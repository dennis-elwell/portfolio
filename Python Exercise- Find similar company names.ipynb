# %% [markdown]
# ## Find similar company names
# Dennis Elwell <br>
# Data: Care, Feeding and Cleaning class (Fall 2019)

# %% [markdown]
# The below exercise, which was from my Data: Care, Feeding and Cleaning class, tasked me to find similar company names using a custom-made similarity function.

# %% [markdown]
# # Our Task: Find similar company names
#
# Let's try to complete a real task, while at the same time trying to practice loops, iterations, and other Python functionality that we studied.
#
# ### Matching Company Names
#
# Quite often, in our data, we have entries represented as strings that refer to the same entity but have different string representations (e.g., McDonald's vs McDonalds vs McDonald). We want to write code that will help in the task of finding such similar entries in our data.
#
# Our task can be broken in the following tasks:
# * **Step 1**: Read the data from a file into a list of strings in memory (one string per line). For our source of company names, we use uniquenames.txt. We need to write Python code that will read these files and return a list of company names.
# * **Step 2**: We will then need to figure out how to compare two strings and find their similarity. For that, we need to write a function that takes as input two strings, and returns back their similarities (we will see below how to do that).
# * **Step 3**: We will need to write a function that takes as input a company name, and returns back a list of matching company names, together with their similarity. Ideally, we would like to also sort the list based on the similarity (highest similarity metrics on top). You can use the _list comprehension_ approach to create the list. We will also use tuples as the elements of the list, so that the list contain elements such as `[("McDonalds", 0.88), ("McDonald's", 0.81),....]`.
# * **Step 4**: In the final step, we will just perform the similarity computation across all companies in the dataset.

# %% [markdown]
# ### STEP 1: Read the list of names from a file and store them the list `names`

# %%
# STEP 1: Read the list of names from a file and create a list of names
with open("uniquenames.txt", "r") as f:
    names = f.read()
names = names.split("\n")
names
# Out:
# ['#1 GARDEN CHINESE',
#  "#1 ME. NICK'S",
#  '#1 SABOR LATINO RESTAURANT',
#  '$1.25 PIZZA',
#  "''U'' LIKE CHINESE RESTAURANT",
#  "''W'' CAFE",
#  "'WICHCRAFT",
#  '(LEWIS DRUG STORE) LOCANDA VINI E OLII',
#  '(LIBRARY)  FOUR & TWENTY BLACKBIRDS',
#  '(PUBLIC FARE) 81ST STREET AND CENTRAL PARK WEST (DELACORTE THEATRE)',
#  "/ L'ECOLE",
#  '002 MERCURY TACOS LLC',
#  '1 2 3 BURGER SHOT BEER',
#  '1 BANANA QUEEN',
#  '1 BUEN SABOR',
#  '1 DARBAR',
#  '1 EAST 66TH STREET KITCHEN',
#  '1 OAK',
#  '1 OR 8',
#  '1 STOP PATTY SHOP',
#  '1.5 GALBI CORP',
#  '10 DEVOE',
#  '10 POINTS KTV',
#  '100 FUN',
#  '100% PATACON CACHAPA YAROA',
#  '100% SMOOTHIES & EMPANADAS',
#  '1001 NIGHTS',
#  '1001 NIGHTS CAFE',
#  '1005 CATERING',
#  '101 CAFE',
#  '101 DELI',
#  '101 RESTAURANT AND BAR',
#  '102 NOODLES TOWN RESTAURANT',
#  '1020 BAR',
#  '1028 BAR & RESTAURANT EL SALVADORENO ',
#  '104-01 FOSTER AVENUE COFFEE SHOP(UPS)',
#  '1061 CATERING LLC',
#  '107 WEST RESTAURANT',
#  '108 FAST FOOD CORP',
#  '108 LOUNGE - CLUB 108',
#  '1081 FULTON',
#  '10TH AVENUE COOKSHOP',
#  '10TH AVENUE PIZZA & CAFE',
#  '11 STREET CAFE',
#  '111 RESTAURANT',
#  '1174 FULTON CUISINE, HALAL FOOD',
#  '12 CHAIRS',
#  '12 CHAIRS CAFE',
#  '12 CORAZONES RESTAURANT & BAR',
#  '12 CORNERS',
#  '12 CORNERS COFFEE INC',
#  '12 STREET ALE HOUSE',
#  '120 BAY CAFE',
#  '1200 MILES',
#  '121 FULTON STREET',
#  '123 NIKKO',
#  '124 COFFEE SHOP',
#  '128 DUMPLING HOUSE',
#  '12TH STREET BAR & GRILL',
#  '137 BAR & GRILL',
#  '1380 BRONX RIVER CAFE CORP',
#  '149 STEAM FISH CORP.',
#  '14TH STREET PIZZA BAGEL CAFE',
#  '15 CENTRAL PARK WEST RESTAURANT',
#  '15 EAST RESTAURANT',
#  '15 FLAVORS',
#  '15 FLAVORS ',
#  '15 ST CAFE',
#  '156 TEX BAR AND LOUNGE',
#  '16 HANDLES',
#  '16 HANDLES FROZEN YOGURT',
#  '16 HANDLES MIDWOOD',
#  '1617-A NATIONAL BAKERY',
#  '162 EB CORP BAKERY',
#  '168 ASUKA SUSHI',
#  '168 BOWERY HOLDING LLC',
#  '168 HI TEA',
#  '168 TEA LLC',
#  '169 BAR',
#  '16TH AVENUE GLATT',
#  '1734 VICTORY BOULEVARD,INC.',
#  '18 BAKERY',
#  '18 CHINESE CUISINE',
#  '18 EAST GUNHILL PIZZA',
#  '18 HIPOT',
#  '18 RESTAURANT',
#  '18 STARS KITCHEN',
#  '181 ST CARIDAD RESTAURANT',
#  '1818 SEAFOOD RESTAURANT',
#  '187 YANG GARDEN',
#  '188 FAST FOOD INC',
#  '19 CAFE',
#  '1962 SOGONGDONG SONTOFU',
#  '19A EMPIRE RESTAURANT',
#  '1A STORE INC',
#  '1ST AVENUE GOURMET',
#  '1ST BASE CONCESSION STAND',
#  '1ST MAMA RESTAURANT',
#  '1ST STOP',
#  '2 BROS',
#  '2 BROS PIZZA',
#  '2 BROTHERS RESTAURANT',
#  '2 CHILL',
#  '2 DUCK GOOSE',
#  '2 IN 1 RESTAURANT',
#  '2 PALMITAS MEXICAN DELI',
#  '200 FIFTH AVENUE RESTAURANT & SPORTS BAR',
#  '200 ORCHARD BAR',
#  '201 BAR AND RESTAURANT',
#  '2013 BROOKLYN RESTAURANT',
#  '203 LENA INC',
#  '2058 DELI AND GROCERY',
#  '21 BAR',
#  '21 CLUB',
#  '21 SHANGHAI HOUSE',
#  '21+ LOUNGE.',
#  '211 NEW TACO GRILL',
#  '212 SHAWARMA GRILL',
#  '212 STEAKHOUSE',
#  '216 GOOD JOY CHINESE RESTAURANT',
#  '218 RESTAURANT',
#  '22 THAI CUISINE',
#  '224TH CORNER RESTAURANT & BAKERY',
#  '229 LINDEN RESTAURANT',
#  '230 FIFTH',
#  '232 WILLIS AVENUE FOODS, LLC',
#  '234 CHINA CITY',
#  '2419 CHINA STAR RESTAURANT',
#  '241ST CAFE RESTAURANT',
#  '2432 PEKING HOUSE INC',
#  '2460 LUCKY GARDEN',
#  '248 HOSPITALITY GROUP LLC',
#  '25TH DELI',
#  '26 SEATS',
#  '2647 DOUBLE DRAGON CHINESE RESTAURANT',
#  '27 SHENG WANG NOODLE SHOP',
#  '27 SHINJUKU SUSHI INC',
#  '27 SPORTS BAR & CAFE',
#  "28 MR. MING'S CAFFE",
#  '28 NOODLES',
#  '286 PIZZA PLACE INC',
#  '29TH STREET HOTEL ACQUISITION LLC',
#  '2A',
#  '2FL',
#  '2ND AVE BLUE 9 BURGER',
#  '2ND AVENUE DELI',
#  '3 ALARM',
#  "3 D'S LEGACY SALAD & GRILL",
#  '3 DELI & GRILL',
#  '3 ESQUINAS RESTAURANT',
#  '3 GUYS',
#  '3 GUYS RESTURANT',
#  '3 IN 1 FS&H JAMAICAN RESTAURANT',
#  '3 IN 1 KITCHEN',
#  '3 MOUNTS',
#  '3 ROOTS',
#  '3 SHEETS SALOON',
#  "3 SISTERS' & SHANTA'S RESTAURANT & BAKERY",
#  '3 STAR JUICE CENTER',
#  '3 WAY RESTAURANT',
#  '3-J RESTAURANT AND PIZZA',
#  '301 CAFE JUICE AND SMOOTHIES',
#  '310 - EXELSIOR',
#  '318 - TWO BOOTS',
#  '31ST AVENUE GYRO.',
#  '32 DEGREE FROYO LOUNGE',
#  '33 GOURMET',
#  '337 - BURGERS & DOGS',
#  '3463 JUICES FOR LIFE LLC',
#  '35 DUET',
#  '36-02 DITMARS COFFEE CORP.',
#  '360 LOUNGE',
#  '36TH AVE COFFEE SHOP',
#  '374 DELI',
#  '38 DELI',
#  '388 CAFE & DELI',
#  '38TH STREET DINER',
#  '39 COFFEE SHOP',
#  '39 KARAOKE',
#  '395 GOURMET AND GROCERY',
#  '3E TASTE OF THAI',
#  '3RD & 7',
#  '40/40 CLUB',
#  '40/40 CLUB BAR',
#  '401 LUCKY STAR RESTAURANT',
#  '40TH ROAD LUNCH BOX',
#  '414 HOTEL',
#  '414 LATINO RESTAURANT SPORTS BAR',
#  '42ND STREET PIZZA DINER',
#  "44 & X HELL'S KITCHEN",
#  '44 1/2 CAFE',
#  '44 SW RISTORANTE & BAR',
#  '444 MADISON COFFEE SHOP',
#  '44TH STREET MINAR',
#  '44TH STREET PIZZA',
#  '456 RESTAURANT',
#  '4618 BAKERY',
#  '46TH ST STATION HOUSE',
#  '49 GROVE',
#  '4D',
#  '4TH DOWN',
#  '4TH FLOOR CAFE',
#  '5 AVENUE ASIAN TASTE',
#  '5 BORO BURGER',
#  '5 BURRO CAFE',
#  '5 DE MAYO',
#  '5 ESTRELLA BAKERY',
#  '5 NAPKIN BURGER',
#  '5 STAR CHEESE STEAK AND PIZZA',
#  '5 STAR CHEESESTEAK AND PIZZA',
#  '5 STAR VILLAGE CAFE',
#  '5 TH & VINE',
#  '502 BAR LOUNGE',
#  '502 HUDSON BAGEL CORP',
#  '508 RESTAURANT AND BAR',
#  '510 11ST BAR',
#  '51ST BAKERY AND CAFE',
#  '525 LEX RESTAURANT & BAR',
#  '52ND SUSHI',
#  '54 BELOW',
#  '55 BAR',
#  '55 DELI & GRILL INC',
#  '55 THOMAS CAFE',
#  '555 VIVACAFE',
#  '556 EL CAFE INTERNATIONAL',
#  "57'S ALL AMERICAN GRILL",
#  '59 CHINA',
#  '59E59 BAR',
#  '5BAR KARAOKE',
#  '5IVE STEAK',
#  '5TH AVENUE BAGELTIQUE CAFE',
#  '5TH AVENUE EMPIRE CAFE',
#  '61 LOCAL',
#  '620 ON CATON',
#  '624 KAM HAI CHINESE FOOD',
#  '6321 YUAN BAO',
#  "652 LIN'S GARDEN",
#  '658 KINGS DELI',
#  '66 HOPE CAFE',
#  '66 PRINCE RESTAURANT',
#  '66TH STREET DONUTS LLC',
#  '67 BURGER',
#  '67 ORANGE STREET',
#  '67 RESTAURANT',
#  '678 AURORA CATERING INC',
#  '68 DELI CANAL STORE',
#  '68 JAY STREET BAR',
#  '68 MEI MEI BAKERY',
#  '69 BAR LOUNGE',
#  '69 BAYARD RESTAURANT',
#  '69 COFFEE SHOP',
#  '69 PIZZERIA',
#  '696 GOURMET DELI',
#  '6B',
#  '7 GRAMS CAFFE',
#  '7 GREEN & GRAIN',
#  '7 SPICES',
#  '7 STARS',
#  '7 TACOS MEXICAN CUISINE CORP',
#  '706 BAR',
#  '71 IRVING PLACE',
#  '718 HOOKAH LOUNGE',
#  '718 LOUNGE',
#  '718 LOUNGE & TAPAS',
#  '729 BAR & GRILL',
#  '72ND STREET BAGEL',
#  '739 FRANKLIN BAR & LOUNGE',
#  '76/BEERS OF BROOKLYN',
#  '765 FOOD MARKET',
#  '773 LOUNGE',
#  '777 THEATER BAR',
#  '7B BAR',
#  '7TH AVENUE DONUT SHOP',
#  '7TH FLOOR CAFE',
#  '7TH MANSION KTV',
#  '8 DRAGON & PHOENIX CHINESE RESTAURANT',
#  '8 PAET RIO',
#  '80 RIVERSIDE CAFE',
#  '805 ZHENG YUAN BAO GOURMET',
#  '809 GRILL & BAR RESTAURANT',
#  '809 PERFECT DELI.',
#  '8090 TAI WANESE',
#  '810 DELI & CAFE',
#  '829 BAR RESTAURANT',
#  '83 1/2',
#  '83 KIEN TUONG RESTAURANT',
#  '833 ANNADALE ROAD CORP.',
#  '85 BROAD CAFE',
#  '85 CHINESE RESTAURANT',
#  '86 BAKERY',
#  '86 BEST BAKERY',
#  '86 NOODLES',
#  '86 SEAFOOD CHINESE RESTAURANT',
#  '86 SUPERSTAR INC',
#  '876 BAR LOUNGE CORP',
#  '876 MARKET DELI',
#  '88 CAFE',
#  '88 CANTEEN',
#  '88 CHINESE RESTAURANT',
#  '88 DEGREES',
#  '88 PALACE RESTAURANT',
#  '888 KITCHEN',
#  '8TH STREET WINECELLAR',
#  '9 & 8 CAFE',
#  '900 PARK',
#  '9024/CATERING BY MICHAEL SCHICK INC.',
#  '904 LUPITA RESTAURANT CORP',
#  '940 FLUSHING LOUNGE/ARANCINI BROS',
#  '95 SOUTH',
#  '96 SOUTH PARK',
#  '983 BUSHWICK LIVING ROOM',
#  '99 CENT BEST PIZZA 5AVE INC',
#  '99 CENT EXPRESS PIZZA',
#  '99 CENT FRESH PIZZA',
#  '99 CENT FRESH PIZZA VILLA CAFE',
#  '99 CENT PIZZA',
#  '99 CENTS BEST & FRESH PIZZA INC.',
#  '99 CENTS FRESH HOT PIZZA',
#  '99 CENTS FRESH SLICE PIZZA',
#  '99 CENTS MEGA PIZZA',
#  '99 FAVOR TASTE',
#  '99 FRESH PIZZA',
#  '99 MILES TO PHILLY',
#  '99C FRESH PIZZA',
#  '99Â¢ FAMOUS PIZZA',
#  '99Â¢ HOT PIZZA',
#  '9A KITCHEN & LOUNGE',
#  '9TH AVE SALOON',
#  '9TH STREET LUNCHEONETTE',
#  '@ THE SQUARE(STARBUCKS)',
#  '@NINE',
#  'A & A BAKE SHOP',
#  'A & B DELI & CATERING',
#  'A & C COFFEE SHOP AND PIZZERIA',
#  'A & C GUYANA BAKERY & RESTAURANT',
#  'A & C KITCHEN',
#  'A & J DELI FISH',
#  'A & K TACOS',
#  'A & M PIZZA',
#  'A & S CATERERS',
#  'A & S PIZZERIA',
#  'A A CARIDAD RESTAURANT',
#  'A ASO SUSHI',
#  'A CAFE',
#  'A CASA FOX',
#  'A CHIBAN',
#  'A DOG AND DUCK',
#  'A K  US GROUP',
#  'A LA SAIGON',
#  'A LE BAGUETTE/ CAFE OLYMPIA',
#  'A LOVE FOR CAKES',
#  'A MARINO RESTAURANT',
#  'A PLATE OF SOUL',
#  'A PLUS EXPRESS/CHINESE RESTAURANT',
#  'A PLUS PIZZA OF NY INC',
#  'A PLUS THAI PLACE',
#  'A SALT & BATTERY',
#  'A SAN FUZHOU RESTAURANT',
#  'A SLICE OF NEW YORK',
#  'A SPICE LANE',
#  'A SUSHI',
#  'A TASTE OF CHINA NO 1 CHINESE FOOD',
#  'A TASTE OF SEA FOOD',
#  'A TASTE OF SHANGHAI RESTAURANT',
#  'A TO Z CATERING',
#  'A VOCE',
#  'A WAI LOU RESTAURANT',
#  'A&A GOURMET',
#  'A&E NETWORKS',
#  'A&E TENOCHTITLAN DELI & TAQUERIA',
#  'A&L PIZZA RESTAURANT',
#  'A&M WESTINDIES AMERICAN RESTAURANT',
#  'A&P ROTI & PASTRY SHOP',
#  'A&R HOT BAGELS',
#  'A+ CHINESE RESTAURANT',
#  'A+ LOLLIPOP',
#  'A-1 PIZZA SHOP',
#  'A-12 SUSHI & RAMEN',
#  'A-JIAO SICHUAN CUISINE',
#  'A-ROMA BAKERY',
#  'A-TOWN BUFFALO WINGS',
#  'A-WAH RESTAURANT',
#  'A. A. CARIDAD RESTAURANT',
#  'A. CHURRASQUEIRA RESTAURANT',
#  'A. KAWAII JAPANESE RESTAURANT',
#  'A.G KITCHEN',
#  'A.I.G.CHARTIS',
#  'A.J. PIZZERIA',
#  'A.K.A. RESTAURANT',
#  "A.R'S TAVERN",
#  'A.W.O.L. ALL WALKS OF LIFE',
#  'A1 OCHA SUSHI',
#  "AA ADMIRAL'S CLUB LOUNGE",
#  'AA CHINESE RESTURANT',
#  'AA ICHIBAN SUSHI',
#  'AA JING',
#  'AAA BURRITO MARIACHI',
#  'AAA CARIDAD',
#  'AAA ICHIBAN SUSHI',
#  'AAA KENNEDY FRIED CHICKEN',
#  'AAHELI',
#  'AAMANNS-COPENHGEN',
#  'AANCHAL INDIAN RESTAURANT & BAR',
#  'AANGAN',
#  'AARONS CHINESE & THAI RESTAURANT',
#  'AB BIAGI',
#  'AB HALAL RESTAURANT',
#  'ABA ASIAN FUSION CUISINE AVE',
#  'ABA TURKISH RESTAURANT',
#  'ABACE SUSHI',
#  'ABACKY POTLUCK',
#  'ABALEH',
#  'ABBOCCATO RISTORANTE',
#  'ABBY CHINESE RESTAURANT',
#  'ABC BAKERY',
#  'ABC BEER CO.',
#  'ABC COCINA',
#  'ABC KITCHEN',
#  'ABDULLAH SWEETS AND RESTAURANT',
#  'ABECA SUSHI',
#  "ABEGALE'S ",
#  'ABI JAPANESE RESTAURANT',
#  'ABIDE BROOKLYN PITA',
#  "ABIGAEL'S BROOKLYN",
#  "ABIGAEL'S ON BROADWAY",
#  'ABILENE',
#  'ABIR HALAL RESTAURANT',
#  "ABITINO'S PIZZA",
#  'ABOTTEGA',
#  'ABOU BAKERY',
#  'ABOVE ALLEN',
#  'ABOVE BALLROOM',
#  'ABOVE ROOFTOP',
#  'ABRACO',
#  'ABRAHAM JOSHUA HESCHEL SCHOOL',
#  'ABSOLUTE BAGELS',
#  'ABSOLUTE COFFEE',
#  'ABSOLUTE THAI RESTAURANT',
#  'ABU DHABI LOUNGE',
#  "ABU'S HOMESTYLE BAKERY",
#  'ABUMI SUSHI',
#  'ABURI SUSHI',
#  'ABURIYA KINNOSUKE',
#  'ABV',
#  'ABYSSINIA ETHIOPIAN RESTAURANT',
#  'ACADEMIA BARILLA RESTAURANTS',
#  'ACADEMIA COFFEE',
#  'ACADEMY RESTAURAUNT',
#  'ACAPELLA GOURMET PIZZA & RESTAURANT CORP',
#  'ACAPPELLA RESTAURANT',
#  'ACAPULCO',
#  'ACAPULCO BAR RESTAURANT',
#  'ACAPULCO DELI & RESTAURANT',
#  'ACCCORD ASIAN CUISINE',
#  'ACCRA RESTAURANT',
#  'ACE BAGEL & ROLL',
#  'ACE BAR',
#  'ACE HOT BAGEL & DELI',
#  'ACE PIZZA',
#  'ACELUCK THAI',
#  "ACEY DUCEY'S",
#  'ACHILLES HEEL',
#  'ACME BAR & GRILL',
#  'ACOSTA RESTAURANT',
#  'ACQUA',
#  'ACQUA RESTAURANT',
#  'ACQUA SANTA',
#  'ACQUISTA FOOD SERVICE II INC.',
#  'ACQUISTA TRATTORIA',
#  'ACQUOLINA CATERING',
#  'ACTION BURGER',
#  'ACTIVE HEALTH',
#  'ACUARIO CAFE',
#  'ADAM CHINESE COTTAGE',
#  'ADAM KOSHARY & GRILL',
#  'ADANA GRILL',
#  'ADAR LOUNGE',
#  'ADAYA AFRICAN AMERICAN RESTAURANT',
#  "ADDEO'S RIVERDALE PIZZERIA",
#  "ADELINA'S",
#  'ADELLA',
#  'ADEN RESTAURANT',
#  'ADIRONDACK',
#  'ADMIRALS CLUB CONC C',
#  'ADOBE BLUES',
#  'ADONAI DELI GROCERY INC',
#  'ADORO LEI ',
#  'ADP INNOVATIONS LAB',
#  'ADRIA HOTEL',
#  "ADRIAN & ROCKY'S CATERERS",
#  'ADRIATIC RESTAURANT PIZZERIA BAR',
#  "ADRIENNE'S PIZZA BAR",
#  'ADVENTURES AMUSEMENT PARK',
#  'ADVENTURES AMUSEMENTS PARK',
#  'ADYAR ANANDA BHAVAN',
#  'AEGEA GYROS AND PIZZA',
#  'AENOS PIZZA',
#  'AERONUOVA',
#  'AFGAN KEBAB AND GRILL',
#  'AFGHAN KEBAB HOUSE',
#  'AFGHAN KEBAB HOUSE #1',
#  'AFGHAN KEBOB HOUSE',
#  'AFRICAN AMERICAN BEST FOOD',
#  'AFRICAN LAST STOP',
#  'AFRICAN MAQUIS LA PLANTATION',
#  'AFRICAN MARKET (BABOON CAFE)',
#  'AFRICAN TERRACE',
#  'AFRICANA RESTAURANT',
#  'AFRIKIKO GARDEN',
#  'AFTER 8',
#  "AFTERNOONE'S RESTAURANT",
#  'AGAINST THE GRAIN',
#  'AGAVE',
#  'AGAVE DELI GROCERY',
#  'AGAVE MEXICAN & AMERICAN GRILL',
#  'AGED',
#  'AGEHA JAPANESE FUSION',
#  'AGNANTI CAFE',
#  'AGNANTI RESTAURANT',
#  'AGODA ASIAN CUISINE',
#  'AGORA TAVERNA',
#  'AGORA TURKISH RESTAURANT',
#  'AGOZAR',
#  'AGRA HEIGHTS',
#  'AGRA KING RESTAURANT',
#  'AGRA RESTAURANT',
#  'AGRA TAJ MAHAL',
#  'AGREEN RANCHO MEXICAN RESTAURANT',
#  'AGUA FRESCA- TAPAS BAR EL KALLEJON',
#  'AGUA ROJA BAR & LOUNGE',
#  'AH YAH SUH NICE',
#  'AH! CHIHUAHUA',
#  'AH2 ICE TEA',
#  'AHANA JAPANESE FUSION CUISINE INC',
#  'AHI SUSHI',
#  "AHMANI'S JUS JUICE & HEALTH KITCHEN",
#  'AHOME EATERY',
#  'AHUACHAPAN',
#  'AI FIORI',
#  'AI ZHEN FOO CHOW RESTAURANT',
#  "AI'S SUSHI JAPANESE RESTAURANT",
#  'AIDA CHIMPBAY',
#  'AIG 31ST FLOOR CAFE',
#  'AIKO SUSHI JAPANESE RESTAURANT (JINSHU SUSHI)',
#  'AILEY BOUTIQUE',
#  'AINSWORTH PARK',
#  'AIR BAR/ NY DELI/ TIM HORTONS',
#  'AIR FRANCE LOUNGE',
#  'AIR INDIA LOUNGE',
#  'AIRPORT DELI',
#  'AIRSPACE LOUNGE',
#  'AIRWAYS PIZZA & GYRO RESTAURANT',
#  'AITA RESTAURANT',
#  'AJ PIZZERIA',
#  "AJ'S HOMEMADE GOURMET ITALIAN ICE & ICE CREAM",
#  'AJANTA INDIA',
#  'AJI 18',
#  'AJI SUSHI',
#  'AJI SUSHI HOUSE',
#  'AJISAI',
#  'AJISAI JAPANESE RESTAURANT',
#  'AJISEN RAMEN',
#  'AKA 99 CENTS FRESH PIZZA',
#  'AKA MY HOUSE',
#  'AKA SUSHI JAPANESE RESTAURANT',
#  'AKAL BAKERY INC',
#  'AKAMI SUSHI',
#  'AKARU SUSHI',
#  'AKDENIZ',
#  'AKI 39 JAPANESE CUISINE',
#  'AKI JAPANESE CUISINE',
#  'AKI SUSHI',
#  'AKI SUSHI & GRILL',
#  'AKI SUSHI WEST',
#  'AKIMOTO SUSHI',
#  'AKIN GUMP',
#  'AKINA SUSHI',
#  'AKIRA JAPANESE CUISINE',
#  'AKIYAMA JAPANESE RESTAURANT',
#  'AKO ASIAN FUSION',
#  'AKO JAPANESE RESTAURANT',
#  'AKSARAY TURKISH CAFE AND RESTAURANT',
#  'AKURA SUSHI',
#  'AKWAABA RESTAURANT',
#  'AL BUSTAN RESTAURANT',
#  'AL CHOLO BAKERY',
#  'AL DENTE PIZZERIA',
#  'AL DI LA',
#  'AL FORNO',
#  'AL GOLDEN LION DELI',
#  'AL HIRSCHFELD THEATRE',
#  'AL HORNO LEAN MEXICAN',
#  'AL HORNO LEAN MEXICAN KITCHEN INC',
#  'AL NAIMAT RESTAURANT & SWEETS',
#  'AL SAFA',
#  "AL'S DELI",
#  'AL-ARAF HALAL FRIED CHICKEN AND FROZEN DELIGHTS',
#  'AL-DENTE',
#  'AL-MEHRAN RESTAURANT',
#  'AL-RAHAMANIA RESTAURANT AND CATERING',
#  'ALA TURKA',
#  'ALACHI MASALA INDIAN RESTAURANT',
#  'ALADDIN',
#  'ALADDIN GRILL',
#  'ALADDIN HOOKAH LOUNGE & BAR INC',
#  'ALAMEDA',
#  'ALARCON DELI INC',
#  'ALASKA BAR',
#  'ALBA BAR CAFE',
#  'ALBA PIZZA',
#  "ALBA'S PIZZA",
#  'ALBANY MANOR',
#  'ALBELLA RISTORANTE & BAR',
#  "ALBERT'S COFFEE SHOP",
#  "ALBERTO'S",
#  'ALCALA RESTAURANT',
#  'ALCHEMY',
#  'ALDEA RESTAURANT',
#  'ALDER',
#  "ALDO'S II PIZZA AND RESTAURANT",
#  'ALE HOUSE CITY ISLAND',
#  'ALEEF COFFEE HOUSE',
#  'ALEGRE DESPERTAR',
#  'ALEMBI CAFE',
#  'ALEO',
#  'ALEPPO SLIDER',
#  'ALEWIFE',
#  'ALEX CAFE & DELI',
#  'ALEX LUNCHEONETTE',
#  'ALEX STEAK HOUSE BAR & CAFE',
#  "ALEX'S KITCHEN",
#  'ALEXANDRA',
#  'ALFANOOSE',
#  "ALFIE'S",
#  "ALFIE'S PIZZA",
#  "ALFIE'S PLACE",
#  "ALFONSO'S BAR",
#  "ALFONSO'S PASTRY SHOPPE",
#  'ALFREDO 100',
#  'ALGONQUIN HOTEL',
#  'ALHPA RESTAURANT',
#  'ALI BABA',
#  'ALI BABA RESTAURANT',
#  "ALI BABA'S",
#  "ALI'S ROTI SHOP",
#  "ALI'S TRINIDAD ROTI SHOP",
#  'ALIADA',
#  'ALIBABA',
#  'ALIBABA EXPRESS',
#  'ALIBABA GRILL',
#  'ALIBI CLUB',
#  "ALICE'S ARBOR",
#  "ALICE'S CAFE",
#  "ALICE'S INT'L CAFE",
#  "ALICE'S PALACE",
#  "ALICE'S TEA CUP",
#  'ALICES',
#  'ALICES TEA CUP CHAPTER 2',
#  'ALIDORO',
#  'ALIMENTOS SALUDABLES - MEXICAN GRILL',
#  'ALIOTTA BAKE SHOP',
#  'ALITALIA - COMPAGNIA AEREA ITALIANA',
#  'ALITALIA PIZZA RESTAURANT',
#  'ALKOURA RESTAURANT',
#  'ALL ABOUT FOOD',
#  'ALL ABOUT INDIAN FOOD',
#  'ALL AMERICAN COFFEE SHOP',
#  'ALL AMERICAN DELI',
#  'ALL NATIONS',
#  'ALL STAR PIZZA',
#  "ALL'ONDA",
#  'ALLADIN',
#  "ALLAN'S BAKERY",
#  'ALLELUIA CHINESE RESTAURANT',
#  'ALLEN RESTAURANT',
#  'ALLERTON DINER',
#  'ALLEY CAT',
#  'ALLEY POND DRIVING RANGE',
#  'ALLIANCE CAPITAL',
#  'ALLIANZ CAFETERIA',
#  'ALLIGATOR LOUNGE',
#  'ALLORO',
#  'ALLSWELL',
#  'ALLURE',
#  'ALMA',
#  'ALMADIRA',
#  'ALMANAC',
#  'ALMANDO RESTAURANT INC',
#  'ALMAR',
#  'ALMASRY RESTAURANT',
#  'ALMAYASS',
#  'ALMAZ RESTAURANT',
#  'ALMOND',
#  'ALMONDINE',
#  'ALNOOR HALAL DELI',
#  'ALOBAR RESTAURANT',
#  'ALOFT HARLEM WXYZ REFUEL',
#  'ALOFT NEW YORK BROOKLYN/BROOKLYN TERRACE',
#  'ALOR CAFE',
#  'ALOR PASTA',
#  "ALOYSIA'S LOUNGE",
#  'ALPHA BAKERY',
#  'ALPHA DONUTS',
#  'ALPHA FUSION',
#  'ALPHABET LOUNGE',
#  'ALPHAVILLE',
#  'ALPINE CINEMAS',
#  'ALPINE FOOD TRADERS CORP',
#  'ALSHAM PASTRIES',
#  'ALT - A LITTLE TASTE',
#  'ALTA',
#  'ALTESI RISTORANTE',
#  "ALTON'S PIZZA & DELI",
#  'ALTUS CAFE',
#  'ALWAYS HAPPY FOOD LLC',
#  'ALYSHIA ALEEM COFFEE SHOP',
#  'AM',
#  'AM PLANNING GROUP LTD',
#  'AM THAI BISTRO',
#  'AMADEUS',
#  'AMALI',
#  'AMAN RESTAURANT',
#  "AMANDA'S KITCHEN",
#  'AMANECER LATINO RESTAURANT',
#  'AMARACHI PRIME',
#  'AMARANTH',
#  'AMARANTO',
#  'AMARETTO ESPRESSO BAR',
#  'AMARIN CAFE',
#  'AMARONE RESTAURANT',
#  'AMARU',
#  'AMAZE',
#  'AMAZE FUSION LOUNGE',
#  'AMAZING 66 RESTAURANT',
#  'AMAZON CAFE',
#  'AMBAR',
#  'AMBASSADOR DINER',
#  'AMBASSADOR DINING ROOM  AT SARATOGA FAMILY INN',
#  'AMBASSADOR FOOD SERVICES',
#  'AMBASSADOR THEATRE',
#  'AMBER',
#  'AMBER STEAK HOUSE',
#  'AMBER VILLAGE  SUSHI AND THAI',
#  'AMBIANCE EXPRESS',
#  'AMBROSE HALL',
#  'AMBROSIA',
#  "AMBROSINO'S II",
#  'AMBROSINOS PIZZERIA',
#  "AMBY'S RESTAURANT",
#  'AMC EMPIRE 25 THEATRES',
#  'AMC KINGS VILLAGE 7 MAIN LEVEL',
#  'AMC LOEWS VILLAGE 7 (3RD FL CONCESSION)',
#  'AMC ORPHEUM 7',
#  'AMC THEATERS 34TH STREET - MAIN CONCESSION',
#  'AMC THEATRES (LOWES)  34TH STREET - AUXILLIARY CONCESSION',
#  'AMC THEATRES 19TH STREET EAST',
#  'AMC THEATRES 84TH STREET',
#  'AMC THEATRES BAY PLAZA',
#  'AMC THEATRES EMPIRE 25',
#  'AMC THEATRES FRESH MEADOWS 7',
#  'AMC THEATRES LINCOLN SQUARE',
#  'AMC THEATRES MAGIC JOHNSON HARLEM 9',
#  'AMC/LOWES THEATRES KIPS BAY',
#  'AMCOOK FUSION SUSHI & ASIAN CUISINE',
#  "AMELIA'S RESTAURANT",
#  'AMELIE',
#  'AMELIO RUSSO CIVIC',
#  'AMERADA HESS EXPRESS CAFE',
#  'AMERICA GOURMET FOOD',
#  'AMERICAN & LATIN CUISINE',
#  'AMERICAN AIRLINES ADMIRALS CLUB',
#  'AMERICAN AIRLINES EMPLOYEE CAFETERIA',
#  'AMERICAN AIRLINES THEATER',
#  'AMERICAN BAR',
#  'AMERICAN CHEEZ',
#  'AMERICAN COFFEE SHOP',
#  'AMERICAN CUT',
#  'AMERICAN EXPRESS',
#  'AMERICAN FLATBREAD TRIBECA HEARTH',
#  'AMERICAN GIRL CAFE',
#  "AMERICAN HERO & SUB'S",
#  'AMERICAN HERO EXPRESS',
#  'AMERICAN LANGUAGE COMMUNICATION CENTER CAFETERIA',
#  'AMERICAN LEGION VETERANS POST',
#  'AMERICAN MUSEUM OF NATURAL HISTORY FOOD COURT',
#  'AMERICAN MUSEUM OF THE MOVING IMAGE',
#  'AMERICAN RETRO BAR & GRILL',
#  'AMERICAN TABLE CAFE AND BAR',
#  'AMERICAN TURNERS NEW YORK',
#  'AMERICAN WHISKEY',
#  'AMERICAS BURGER AND WRAPS',
#  'AMERICAS RESTORANTE',
#  'AMERICO FOOD MARKET',
#  'AMERIVENTS CATERING ',
#  'AMF 34 AVENUE LANES',
#  'AMICI 36',
#  'AMICI BAKERY',
#  'AMICI BAR',
#  'AMICI BRICK OVEN PIZZA',
#  'AMICI CAFE',
#  'AMICI II',
#  'AMICI PIZZA AND PASTA',
#  'AMICI PIZZERIA',
#  'AMIGOS MEXICAN BAR & RESTAURANT',
#  'AMIGOS RESTAURANT, INC',
#  'AMINA THAI',
#  "AMIR'S",
#  "AMIRA'S",
#  'AMITY HALL',
#  'AMLA CUISINE OF INDIA',
#  'AMMA',
#  'AMMOS ESTIATORIO',
#  'AMNON KOSHER PIZZA',
#  'AMOR BAKERY NO 2',
#  'AMOR CUBANO',
#  'AMOR KARAOKE & BAR',
#  'AMORE PIZZERIA & RESTAURANT',
#  'AMORINA',
#  'AMORINO',
#  'AMPLE HILLS CREAMERY',
#  'AMSTERDAM ALE HOUSE',
#  'AMSTERDAM BILLIARDS',
#  'AMSTERDAM BURGER CO.',
#  'AMSTERDAM GOURMET',
#  'AMSTERDAM RESTAURANT & TAPAS LOUNGE',
#  'AMSTERDAM SOCIAL',
#  'AMSTERDAM TAVERN',
#  'AMURA JAPANESE RESTAURANT',
#  'AMUSE WINE BAR',
#  "AMY & CATHY'S CHINESE RESTAURANT",
#  "AMY RUTH'S RESTAURANT",
#  "AMY'S BREAD",
#  "AMY'S CAFE AND BAKERY",
#  "AMY'S RESTAURANT",
#  'AN BEAL BOCHT CAFE',
#  'AN CHOI',
#  "ANA'S BAKERY & CAFE",
#  "ANA'S PASTRY SHOP CORP.",
#  'ANABLE BASIN SAILING',
#  'ANAIAH RESTAURANT',
#  'ANALOGUE',
#  'ANARKALI INDIAN FOOD',
#  'ANASSA TAVERNA',
#  'ANATOLIA MEDITERRANEAN CUISINE',
#  'ANATOLIAN GYRO RESTAURANT',
#  'ANCHOR',
#  'ANCHOR COFFEE',
#  'ANCHOR INN',
#  'ANCHOR WINEBAR LLC',
#  'ANDALUCIA BAR & LOUNGE',
#  'ANDAMAN THAI BISTRO',
#  'ANDANADA',
#  'ANDAZ',
#  'ANDAZ FIFTH AVENUE',
#  'ANDIAMO CAFE',
#  "ANDRE'S CAFE",
#  "ANDRE'S HUNGARIAN",
#  "ANDRE'S HUNGARIAN STRUDELS & PASTRIES",
#  "ANDRE'S PIZZA",
#  "ANDREA'S CHICKEN",
#  "ANDREA'S RESTAURANT (JG DELICIOUS FOOD)",
#  'ANDRES CARNE DE TRES',
#  "ANDREW & FRANK'S DELI",
#  "ANDREW'S COFFEE SHOP",
#  "ANDREW'S DINER",
#  "ANDREW'S PIZZERIA",
#  'ANDREWS COFFEE SHOP',
#  'ANDY BOY MEXICAN RESTAURANT',
#  "ANDY'S CAFE",
#  "ANDY'S CAFETERIA",
#  "ANDY'S CAFETERIA (HPD BUILDING)",
#  "ANDY'S DELI",
#  "ANDY'S RESTAURAUNT",
#  "ANDY'S TERIYAKI & TACO",
#  'ANEJO',
#  'ANEJO TRIBECA',
#  'ANELLA',
#  'ANESIS CAFE',
#  'ANFORA',
#  'ANGEBIENVENDIA',
#  'ANGEL CANDY STORE',
#  'ANGEL FLAKES PATTIES',
#  "ANGEL'S 1 BAKERY",
#  "ANGEL'S GRILL",
#  'ANGELA CAKE',
#  'ANGELA RESTAURANT OF NY',
#  "ANGELA'S BAKERY",
#  "ANGELA'S PIZZERIA",
#  "ANGELA'S ROCK AND ROLL DELI",
#  "ANGELA'S TACO",
#  'ANGELICA KITCHEN',
#  'ANGELICA PIZZERIA',
#  "ANGELICA'S BAKERY",
#  'ANGELIKA FILM CENTER',
#  'ANGELINA',
#  'ANGELINA GOURMET FOODS',
#  "ANGELINA'S PANINI BAR",
#  "ANGELINA'S RISTORANTE",
#  'ANGELINAS PIZZA',
#  'ANGELITA RESTAURANT',
#  "ANGELO & AL'S PIZZERIA",
#  'ANGELO BELLINI',
#  'ANGELO GORDON & COMPANY',
#  'ANGELO OF MULBERRY ST.',
#  "ANGELO'S DELI",
#  "ANGELO'S PIZZA",
#  "ANGELO'S PIZZA RESTAURANT",
#  "ANGELO'S PIZZERIA",
#  "ANGELO'S PIZZERIA & B B Q",
#  "ANGELO'S PIZZERIA/MIMMO'S RESTAURANT",
#  'ANGELOS DELI RESTAURANT',
#  'ANGELOS PIZZA & DELI',
#  "ANGIE'S BREAKFAST SPOT",
#  "ANGIE'S CAFE PIZZA",
#  'ANGLERS CLUB OF NEW YORK',
#  'ANGRY WADES',
#  'ANGUS CLUB STEAKHOUSE',
#  'ANI PIZZA',
#  'ANI SUSHI',
#  "ANIL'S ROTI SHOP",
#  "ANITA'S LUNCHEONETTE",
#  "ANITA'S ROTI SHOP LLC.",
#  'ANJAPPAR CHETTINAD SOUTH INDIAN CUISINE',
#  'ANKA GRILL',
#  "ANN & TONY'S RESTAURANT",
#  'ANN STREET HOTEL LLC',
#  'ANN TAYLOR',
#  'ANNA MARIA PIZZA PASTA',
#  "ANNA'S CAFE",
#  'ANNABEL',
#  'ANNADALE TERRACE',
#  'ANNAM BRAHAM RESTAURANT',
#  'ANNELIES PASTRIES',
#  'ANNIE 88 EXPRESS',
#  "ANNIE CHAN'S RESTAURANT",
#  "ANNIE MOORE'S RESTAURANT",
#  "ANNIE'S KITCHEN",
#  'ANNIES FIRST WOK RESTAURANT',
#  'ANOPOLI FAMILY RESTAURANT',
#  'ANOTHEROOM',
#  'ANTALIA TURKISH CUISINE',
#  'ANTEK RESTAURANT',
#  "ANTHI'S GREEK FOOD",
#  "ANTHONY & JOE'S PIZZA",
#  'ANTHONY AND SON PANNINI SHOPPE',
#  'ANTHONY CAFE',
#  "ANTHONY'S",
#  "ANTHONY'S PIZZA",
#  "ANTHONY'S PLACE",
#  "ANTHONY'S RESTAURANT & PIZZERIA",
#  'ANTIBES BISTRO',
#  'ANTICA BOTTEGA DEL VINO',
#  'ANTICA PESA',
#  'ANTICA TRATTORIA',
#  'ANTIKA PIZZERIA',
#  'ANTILLANA PIZZERIA',
#  'ANTINORI RISTORANTE',
#  'ANTIOCH MISSIONARY CHURCH',
#  'ANTIQUE  BAKERY & CAFE',
#  'ANTIQUE CAFE & BAKERY III INC',
#  'ANTIQUE GARAGE',
#  'ANTIVARI PIZZA',
#  'ANTLER BEER & WINE DISPENSARY',
#  'ANTOJITOS',
#  'ANTOJITOS DELI FOOD',
#  'ANTOJITOS ECUATORIANOS',
#  'ANTOJITOS MEXICANOS',
#  'ANTOJITOS RETAURANT',
#  "ANTONIO'S",
#  "ANTONIO'S PIZZA",
#  "ANTONIO'S PIZZERIA",
#  "ANTONIO'S RESTAURANT",
#  "ANTONIO'S TRATTORIA",
#  "ANTONIONI'S",
#  'ANTONUCCI',
#  "ANTUN'S",
#  'ANYWAY CAFE',
#  'ANYWAY CAFE BAR',
#  'AO FENG RESTAURANT',
#  'AOA BAR & GRILL',
#  'AOYAMA SUSHI',
#  'AOYU SUSHI',
#  'AP CAFE',
#  'APANI',
#  'APERION PRODUCTION',
#  'APERITIF BAYSIDE LLC',
#  'APERITIVO DI PALMA',
#  'APERITIVO PIZZA BAR',
#  'APERTURE',
#  'APHRODITES SWEETS',
#  'APICIUS PIZZA',
#  'APIZZ RESTAURANT',
#  'APNAR PHARMACY',
#  'APOLLO BAKERY',
#  'APOLLO THEATRE CONCESSIONS',
#  'APOLO RESTAURANT',
#  'APOTHEKE',
#  'APPETITE NYC LLC',
#  'APPETITO RESTAURANT',
#  'APPLE GARDEN',
#  ...]

# %% [markdown]
# ### STEP 2: Implement the similarity function

# %% [markdown]
# ### Computing the similarity between two strings
#
# There are many ways that we can calculate the similarity between two strings (e.g., see [1](http://en.wikipedia.org/wiki/String_metric), [2](http://en.wikipedia.org/wiki/Approximate_string_matching), [3](http://en.wikipedia.org/wiki/Plagiarism_detection), [4](https://www.cs.cmu.edu/~pradeepr/papers/ijcai03.pdf), [5](http://en.wikipedia.org/wiki/Category:String_similarity_measures), and links within).
#
# For our example, we will use the q-gram similarity metric. What is a q-gram? Simply a sequency of q-consecutive characters in the string. For example, the name "Konstantin" has the following 2-grams: "Ko", "on", "ns", "st", "ta", "an", "nt", "ti", "in". Strings that share a large number of q-grams are often similar.
#
# Hence, we can compute the similarity of two strings by first computing the set of q-grams for each string, and then compute the Jaccard coefficient between these sets. The [Jaccard coefficient](http://en.wikipedia.org/wiki/Jaccard_index) is simply defined as the size of the intersection divided by the size of the union of the two sets.
#
# So, our task can be broken into two functions:
# * The first function takes a string and returns a list of the q-grams for the string, and
# * The second function takes as input two sets, and returns back their Jaccard coefficient.

# %%
# STEP 2: Now we implement our similarity function

# This returns a list of q-grams for a name
# getQgrams("Konstantin", 1) should return ["K", "o", "n", "s", "t", "a", "n", "t", "i", "n"]
# getQgrams("Konstantin", 2) should return ["Ko", "on", "ns", "st", "ta", "an", "nt", "ti", "in"]
# etc
def getQgrams(name, q):
    char_list =list()
    for i in range(0,len(name)+1-q):
        char = name[i:i+q]
        char_list.append(char)
    return char_list

# This function takes as input two names, computes their qgrams, and then computes
# the Jaccard coefficient (=intersection/union) of the two sets of qgrams

def jaccard(setA, setB):
    SetA_Qgrams = set(getQgrams(setA,2))
    SetB_Qgrams = set(getQgrams(setB,2))
    return len(SetA_Qgrams.intersection(SetB_Qgrams))/len(SetA_Qgrams.union(SetB_Qgrams))

def computeSimilarity(name1, name2, q):
    #your code is here
    Name1_Qgrams = set(getQgrams(name1.lower(),q))
    Name2_Qgrams = set(getQgrams(name2.lower(),q))
    return len(Name1_Qgrams.intersection(Name2_Qgrams))/len(Name1_Qgrams.union(Name2_Qgrams))

getQgrams("Konstantin", 2)
# Out:
# ['Ko', 'on', 'ns', 'st', 'ta', 'an', 'nt', 'ti', 'in']

# %%
# Let's test our similarity function
print(computeSimilarity("Peter", "Pete", 2))
# Out:
# 0.75

# %%
# Let's test our similarity function
print(computeSimilarity("Microsoft", "Micrsoft", 3))
print(computeSimilarity("Microsoft", "Micrsoft", 2))
print(computeSimilarity("Microsoft", "Micrsoft", 1))
print(computeSimilarity("Microsoft", "Google", 3))
print(computeSimilarity("Microsoft", "Google", 2))
print(computeSimilarity("Microsoft", "Google", 1))
# Out:
# 0.4444444444444444
# 0.6666666666666666
# 1.0
# 0.0
# 0.0
# 0.09090909090909091

# %% [markdown]
# ### STEP 3: Compute similarity of a company against a list of company names

# %% [markdown]
# We now create a function that accepts a company name and a list of companies, and computes their similarity. This part will get us to exercise our for-loops, and also illustrate how we can use lists and tuples.

# %% [markdown]
# **HINT: Sorting a list of tuples**:_This part is a little bit advanced for now, so I will just give the code below.

# %%
data = [("Konstantin",0.01), ("Peter",0.6), ("Pan", 0.4)]
# sorts in place, in descending order, based on the second element of the tuple
data.sort(key=lambda tupl: tupl[1], reverse=True)  
print(data)
# Out:
# [('Peter', 0.6), ('Pan', 0.4), ('Konstantin', 0.01)]

# %%
# STEP 3: We now create a function that takes a company name
# and a list of companies, and computes their similarity.
# We also have a threshold parameter (by default set to be 0.5)
# that restricts the results to only string pairs with similarity
# above the threshold. Finally, we have parameter q for Qgrams. 

# queryData finds similar names to a query
def companySimilarity(companyName, companyList, threshold = 0.5, q = 3):
    similar_companies = list()
    for company in companyList:
        similarity = computeSimilarity(companyName,company,q)
        if similarity > threshold:
            similar_companies.append((company,similarity))
    similar_companies.sort(key=lambda tupl: tupl[1], reverse=True)
    return similar_companies

# %%
# This is the name of the restaurant that I am looking for
query = "McDonalds"
# This is the similarity configuration parameter
q = 3
threshold = 0.25
# 'names' variable contains the list of companies from STEP 1
companySimilarity(query, names, threshold, q)
# Out:
# [('MCDONALDS', 1.0),
#  ('MCDONALD', 0.8571428571428571),
#  ("MCDONALD'S", 0.6666666666666666),
#  ("MCDONALD'S ", 0.6),
#  ('MCDONALDS 17754', 0.5384615384615384),
#  ('MC DONALDS', 0.5),
#  ('MCDONALDS (#11542)', 0.4375),
#  ('MCDONALDS RESTAURANT', 0.3888888888888889),
#  ("MC DONALD'S", 0.3333333333333333),
#  ('MCDONALD AVENUE DINER', 0.3),
#  ("MCDONALD'S RESTAURANT", 0.3)]

# %% [markdown]
# ### STEP 4: Perform the similarity computation across all companies in the dataset

# %%
# STEP 4: We are almost done. We now just go through all the companies in the list
# and we call the companySimilarity function that computes the similar company names
# for all the companies in the list. We store the results in a dictionary, with the 
# key being the company name, and the value being a "list of tuples" with the 
# similar company names and the corresponding similarity value.

#your code is here
company_similarity_dict = dict()
for company in names[:20]:
    company_similarity_dict[company] = companySimilarity(company,names,threshold=0.5, q=3)
company_similarity_dict
# Out:
# {'#1 GARDEN CHINESE': [('#1 GARDEN CHINESE', 1.0)],
#  "#1 ME. NICK'S": [("#1 ME. NICK'S", 1.0)],
#  '#1 SABOR LATINO RESTAURANT': [('#1 SABOR LATINO RESTAURANT', 1.0),
#   ('SABOR LATINO RESTAURANT', 0.875),
#   ('NUESTRO SABOR LATINO RESTAURANT CORP', 0.6285714285714286),
#   ('LATINO RESTAURANT', 0.625),
#   ('SABOR LATINO SEAFOOD RESTAURANT', 0.6060606060606061),
#   ('EL REY LATINO RESTAURANT', 0.5517241379310345),
#   ('RANCHO LATINO RESTAURANT', 0.5517241379310345),
#   ('AMANECER LATINO RESTAURANT', 0.5483870967741935),
#   ('RINCON LATINO RESTAURANT', 0.5333333333333333)],
#  '$1.25 PIZZA': [('$1.25 PIZZA', 1.0)],
#  "''U'' LIKE CHINESE RESTAURANT": [("''U'' LIKE CHINESE RESTAURANT", 1.0),
#   ('U LIKE CHINESE RESTAURANT', 0.7857142857142857),
#   ('LEE CHINESE RESTAURANT', 0.6206896551724138),
#   ('85 CHINESE RESTAURANT', 0.5862068965517241),
#   ('88 CHINESE RESTAURANT', 0.5862068965517241),
#   ('A+ CHINESE RESTAURANT', 0.5862068965517241),
#   ('WU CHINESE RESTAURANT', 0.5862068965517241),
#   ('SMILE CHINESE RESTAURANT', 0.5806451612903226),
#   ('BEST CHINESE RESTAURANT', 0.5666666666666667),
#   ('NO1 CHINESE RESTAURANT', 0.5666666666666667),
#   ('WIN CHINESE RESTAURANT', 0.5666666666666667),
#   ('WOK CHINESE RESTAURANT', 0.5666666666666667),
#   ('BAI LI CHINESE RESTAURANT', 0.5625),
#   ('EMPIRE CHINESE RESTAURANT', 0.5625),
#   ('FU KEE CHINESE RESTAURANT', 0.5625),
#   ('HO LEE CHINESE RESTAURANT', 0.5625),
#   ('SUNRISE CHINESE RESTAURANT', 0.5625),
#   ('ABBY CHINESE RESTAURANT', 0.5483870967741935),
#   ('COCO CHINESE RESTAURANT', 0.5483870967741935),
#   ('DI DI CHINESE RESTAURANT', 0.5483870967741935),
#   ('GOOD CHINESE RESTAURANT', 0.5483870967741935),
#   ('JIAN CHINESE RESTAURANT', 0.5483870967741935),
#   ("LY'S CHINESE RESTAURANT", 0.5483870967741935),
#   ('NO 1 CHINESE RESTAURANT', 0.5483870967741935),
#   ('NO 8 CHINESE RESTAURANT', 0.5483870967741935),
#   ('NO.1 CHINESE RESTAURANT', 0.5483870967741935),
#   ('RURAL CHINESE RESTAURANT', 0.5483870967741935),
#   ('CHOY LE CHINESE RESTAURANT', 0.5454545454545454),
#   ('SHUN LI CHINESE RESTAURANT', 0.5454545454545454),
#   ('HUNAN CHINESE RESTAURANT', 0.53125),
#   ("LIN'S CHINESE RESTAURANT", 0.53125),
#   ('LUCKY CHINESE RESTAURANT', 0.53125),
#   ('MAXIM CHINESE RESTAURANT', 0.53125),
#   ('MEI MEI CHINESE RESTAURANT', 0.53125),
#   ('NO. 1 CHINESE RESTAURANT', 0.53125),
#   ('OCEAN CHINESE RESTAURANT', 0.53125),
#   ('PANDA CHINESE RESTAURANT', 0.53125),
#   ('YUM YUM CHINESE RESTAURANT', 0.53125),
#   ('YUMMY CHINESE RESTAURANT', 0.53125),
#   ('CHINA HOUSE CHINESE RESTAURANT', 0.5294117647058824),
#   ('CITY ONE CHINESE RESTAURANT', 0.5294117647058824),
#   ('KANG KEE CHINESE RESTAURANT', 0.5294117647058824),
#   ('MR. RICE CHINESE RESTAURANT', 0.5294117647058824),
#   ('NEW JADE CHINESE RESTAURANT', 0.5294117647058824),
#   ('DRAGON CHINESE RESTAURANT', 0.5151515151515151),
#   ('ELEGANT CHINESE RESTAURANT', 0.5151515151515151),
#   ('FOO ON CHINESE RESTAURANT', 0.5151515151515151),
#   ('HO MEI CHINESE RESTAURANT', 0.5151515151515151),
#   ('JIN XIN CHINESE RESTAURANT', 0.5151515151515151),
#   ('KA WAH CHINESE RESTAURANT', 0.5151515151515151),
#   ('KIM PO CHINESE RESTAURANT', 0.5151515151515151),
#   ('MR CHEN CHINESE RESTAURANT', 0.5151515151515151),
#   ('NY 301 CHINESE RESTAURANT', 0.5151515151515151),
#   ('PEKING CHINESE RESTAURANT', 0.5151515151515151),
#   ('PROFIT CHINESE RESTAURANT', 0.5151515151515151),
#   ("RANDY'S CHINESE RESTAURANT", 0.5151515151515151),
#   ('SAMPAN CHINESE RESTAURANT', 0.5151515151515151),
#   ('WING HING CHINESE RESTAURANT', 0.5151515151515151),
#   ('WO HOP CHINESE RESTAURANT', 0.5151515151515151),
#   ('WO KAI CHINESE RESTAURANT', 0.5151515151515151),
#   ('XING XING CHINESE RESTAURANT', 0.5151515151515151),
#   ('YOU YI CHINESE RESTAURANT', 0.5151515151515151),
#   ('JI LI CHINESE RESTAURANT INC', 0.5142857142857142),
#   ('MOON HOUSE CHINESE RESTAURANT', 0.5142857142857142),
#   ('NEW GRACE CHINESE RESTAURANT', 0.5142857142857142),
#   ('NY DOUBLE CHINESE RESTAURANT', 0.5142857142857142)],
#  "''W'' CAFE": [("''W'' CAFE", 1.0)],
#  "'WICHCRAFT": [("'WICHCRAFT", 1.0), ('WICHCRAFT', 0.875)],
#  '(LEWIS DRUG STORE) LOCANDA VINI E OLII': [('(LEWIS DRUG STORE) LOCANDA VINI E OLII',
#    1.0)],
#  '(LIBRARY)  FOUR & TWENTY BLACKBIRDS': [('(LIBRARY)  FOUR & TWENTY BLACKBIRDS',
#    1.0),
#   ('FOUR & TWENTY BLACKBIRDS', 0.6666666666666666)],
#  '(PUBLIC FARE) 81ST STREET AND CENTRAL PARK WEST (DELACORTE THEATRE)': [('(PUBLIC FARE) 81ST STREET AND CENTRAL PARK WEST (DELACORTE THEATRE)',
#    1.0)],
#  "/ L'ECOLE": [("/ L'ECOLE", 1.0)],
#  '002 MERCURY TACOS LLC': [('002 MERCURY TACOS LLC', 1.0)],
#  '1 2 3 BURGER SHOT BEER': [('1 2 3 BURGER SHOT BEER', 1.0)],
#  '1 BANANA QUEEN': [('1 BANANA QUEEN', 1.0)],
#  '1 BUEN SABOR': [('1 BUEN SABOR', 1.0)],
#  '1 DARBAR': [('1 DARBAR', 1.0)],
#  '1 EAST 66TH STREET KITCHEN': [('1 EAST 66TH STREET KITCHEN', 1.0)],
#  '1 OAK': [('1 OAK', 1.0)],
#  '1 OR 8': [('1 OR 8', 1.0)],
#  '1 STOP PATTY SHOP': [('1 STOP PATTY SHOP', 1.0)]}
